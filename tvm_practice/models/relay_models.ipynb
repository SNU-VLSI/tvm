# %%
import tvm
import tvm.relay as relay
from tvm.contrib.download import download_testdata
import tensorflow as tf
import numpy as np
from PIL import Image
from matplotlib import pyplot as plt
from tensorflow.keras.applications.resnet50 import preprocess_input
import resnet
import ds_cnn
import mobilenet
import deep_autoencoder
from tvm.contrib import relay_viz
from tvm.contrib.relay_viz.interface import (
    VizEdge,
    VizNode,
    VizParser,
)
from tvm.contrib.relay_viz.terminal import (
    TermGraph,
    TermPlotter,
    TermVizParser,
)
import os

# %% [markdown]
# # Resnet

# %%
resnet_model = resnet.resnet_v1_eembc()
img_url = "https://github.com/dmlc/mxnet.js/blob/main/data/cat.png?raw=true"
img_path = download_testdata(img_url, "cat.png", module="data")
img = Image.open(img_path).resize((32, 32))
# input preprocess
data = np.array(img)[np.newaxis, :].astype("float32")
data = preprocess_input(data).transpose([0, 3, 1, 2])
shape_dict = {"input_1": data.shape}
mod, params = relay.frontend.from_keras(resnet_model, shape_dict)
print(mod)
# Out:
# def @main(%input_4, %v_param_1: Tensor[(16, 3, 3, 3), float32], %v_param_2: Tensor[(16), float32], %v_param_3: Tensor[(16), float32], %v_param_4: Tensor[(16), float32], %v_param_5: Tensor[(16), float32], %v_param_6: Tensor[(16), float32], %v_param_7: Tensor[(16, 16, 3, 3), float32], %v_param_8: Tensor[(16), float32], %v_param_9: Tensor[(16), float32], %v_param_10: Tensor[(16), float32], %v_param_11: Tensor[(16), float32], %v_param_12: Tensor[(16), float32], %v_param_13: Tensor[(16, 16, 3, 3), float32], %v_param_14: Tensor[(16), float32], %v_param_15: Tensor[(16), float32], %v_param_16: Tensor[(16), float32], %v_param_17: Tensor[(16), float32], %v_param_18: Tensor[(16), float32], %v_param_27: Tensor[(32, 16, 1, 1), float32], %v_param_28: Tensor[(32), float32], %v_param_19: Tensor[(32, 16, 3, 3), float32], %v_param_20: Tensor[(32), float32], %v_param_21: Tensor[(32), float32], %v_param_22: Tensor[(32), float32], %v_param_23: Tensor[(32), float32], %v_param_24: Tensor[(32), float32], %v_param_25: Tensor[(32, 32, 3, 3), float32], %v_param_26: Tensor[(32), float32], %v_param_29: Tensor[(32), float32], %v_param_30: Tensor[(32), float32], %v_param_31: Tensor[(32), float32], %v_param_32: Tensor[(32), float32], %v_param_41: Tensor[(64, 32, 1, 1), float32], %v_param_42: Tensor[(64), float32], %v_param_33: Tensor[(64, 32, 3, 3), float32], %v_param_34: Tensor[(64), float32], %v_param_35: Tensor[(64), float32], %v_param_36: Tensor[(64), float32], %v_param_37: Tensor[(64), float32], %v_param_38: Tensor[(64), float32], %v_param_39: Tensor[(64, 64, 3, 3), float32], %v_param_40: Tensor[(64), float32], %v_param_43: Tensor[(64), float32], %v_param_44: Tensor[(64), float32], %v_param_45: Tensor[(64), float32], %v_param_46: Tensor[(64), float32], %v_param_47: Tensor[(10, 64), float32], %v_param_48: Tensor[(10), float32]) {
#   %0 = nn.conv2d(%input_4, %v_param_1, padding=[1, 1, 1, 1], channels=16, kernel_size=[3, 3]);
#   %1 = nn.bias_add(%0, %v_param_2);
#   %2 = nn.batch_norm(%1, %v_param_3, %v_param_4, %v_param_5, %v_param_6, epsilon=0.001f);
#   %3 = %2.0;
#   %4 = nn.relu(%3);
#   %5 = nn.conv2d(%4, %v_param_7, padding=[1, 1, 1, 1], channels=16, kernel_size=[3, 3]);
#   %6 = nn.bias_add(%5, %v_param_8);
#   %7 = nn.batch_norm(%6, %v_param_9, %v_param_10, %v_param_11, %v_param_12, epsilon=0.001f);
#   %8 = %7.0;
#   %9 = nn.relu(%8);
#   %10 = nn.conv2d(%9, %v_param_13, padding=[1, 1, 1, 1], channels=16, kernel_size=[3, 3]);
#   %11 = nn.bias_add(%10, %v_param_14);
#   %12 = nn.batch_norm(%11, %v_param_15, %v_param_16, %v_param_17, %v_param_18, epsilon=0.001f);
#   %13 = %12.0;
#   %14 = add(%4, %13);
#   %15 = nn.relu(%14);
#   %16 = nn.conv2d(%15, %v_param_27, strides=[2, 2], padding=[0, 0, 0, 0], channels=32, kernel_size=[1, 1]);
#   %17 = nn.conv2d(%15, %v_param_19, strides=[2, 2], padding=[0, 0, 1, 1], channels=32, kernel_size=[3, 3]);
#   %18 = nn.bias_add(%17, %v_param_20);
#   %19 = nn.batch_norm(%18, %v_param_21, %v_param_22, %v_param_23, %v_param_24, epsilon=0.001f);
#   %20 = %19.0;
#   %21 = nn.relu(%20);
#   %22 = nn.conv2d(%21, %v_param_25, padding=[1, 1, 1, 1], channels=32, kernel_size=[3, 3]);
#   %23 = nn.bias_add(%22, %v_param_26);
#   %24 = nn.batch_norm(%23, %v_param_29, %v_param_30, %v_param_31, %v_param_32, epsilon=0.001f);
#   %25 = nn.bias_add(%16, %v_param_28);
#   %26 = %24.0;
#   %27 = add(%25, %26);
#   %28 = nn.relu(%27);
#   %29 = nn.conv2d(%28, %v_param_41, strides=[2, 2], padding=[0, 0, 0, 0], channels=64, kernel_size=[1, 1]);
#   %30 = nn.conv2d(%28, %v_param_33, strides=[2, 2], padding=[0, 0, 1, 1], channels=64, kernel_size=[3, 3]);
#   %31 = nn.bias_add(%30, %v_param_34);
#   %32 = nn.batch_norm(%31, %v_param_35, %v_param_36, %v_param_37, %v_param_38, epsilon=0.001f);
#   %33 = %32.0;
#   %34 = nn.relu(%33);
#   %35 = nn.conv2d(%34, %v_param_39, padding=[1, 1, 1, 1], channels=64, kernel_size=[3, 3]);
#   %36 = nn.bias_add(%35, %v_param_40);
#   %37 = nn.batch_norm(%36, %v_param_43, %v_param_44, %v_param_45, %v_param_46, epsilon=0.001f);
#   %38 = nn.bias_add(%29, %v_param_42);
#   %39 = %37.0;
#   %40 = add(%38, %39);
#   %41 = nn.relu(%40);
#   %42 = nn.avg_pool2d(%41, pool_size=[8, 8], strides=[8, 8], padding=[0, 0, 0, 0]);
#   %43 = transpose(%42, axes=[0, 2, 3, 1]);
#   %44 = nn.batch_flatten(%43);
#   %45 = nn.dense(%44, %v_param_47, units=10);
#   %46 = nn.bias_add(%45, %v_param_48);
#   nn.softmax(%46, axis=1)
# }

# %%
relay.analysis.count_layers(mod, ["add"])
# Out:
# 3

# %% [markdown]
# # DS-CNN

# %%
Flags, unparsed = ds_cnn.parse_command()
model = ds_cnn.get_model(Flags)
data = np.ones((1, 49, 10, 1)).astype(np.float32)
shape_dict = {"input_1": data.shape}
mod, params = relay.frontend.from_keras(model, shape_dict)
print(mod)
# Out:
# DS CNN model invoked
# def @main(%input_5, %v_param_1: Tensor[(64, 1, 10, 4), float32], %v_param_2: Tensor[(64), float32], %v_param_3: Tensor[(64), float32], %v_param_4: Tensor[(64), float32], %v_param_5: Tensor[(64), float32], %v_param_6: Tensor[(64), float32], %v_param_7: Tensor[(64, 1, 3, 3), float32], %v_param_8: Tensor[(64), float32], %v_param_9: Tensor[(64), float32], %v_param_10: Tensor[(64), float32], %v_param_11: Tensor[(64), float32], %v_param_12: Tensor[(64), float32], %v_param_13: Tensor[(64, 64, 1, 1), float32], %v_param_14: Tensor[(64), float32], %v_param_15: Tensor[(64), float32], %v_param_16: Tensor[(64), float32], %v_param_17: Tensor[(64), float32], %v_param_18: Tensor[(64), float32], %v_param_19: Tensor[(64, 1, 3, 3), float32], %v_param_20: Tensor[(64), float32], %v_param_21: Tensor[(64), float32], %v_param_22: Tensor[(64), float32], %v_param_23: Tensor[(64), float32], %v_param_24: Tensor[(64), float32], %v_param_25: Tensor[(64, 64, 1, 1), float32], %v_param_26: Tensor[(64), float32], %v_param_27: Tensor[(64), float32], %v_param_28: Tensor[(64), float32], %v_param_29: Tensor[(64), float32], %v_param_30: Tensor[(64), float32], %v_param_31: Tensor[(64, 1, 3, 3), float32], %v_param_32: Tensor[(64), float32], %v_param_33: Tensor[(64), float32], %v_param_34: Tensor[(64), float32], %v_param_35: Tensor[(64), float32], %v_param_36: Tensor[(64), float32], %v_param_37: Tensor[(64, 64, 1, 1), float32], %v_param_38: Tensor[(64), float32], %v_param_39: Tensor[(64), float32], %v_param_40: Tensor[(64), float32], %v_param_41: Tensor[(64), float32], %v_param_42: Tensor[(64), float32], %v_param_43: Tensor[(64, 1, 3, 3), float32], %v_param_44: Tensor[(64), float32], %v_param_45: Tensor[(64), float32], %v_param_46: Tensor[(64), float32], %v_param_47: Tensor[(64), float32], %v_param_48: Tensor[(64), float32], %v_param_49: Tensor[(64, 64, 1, 1), float32], %v_param_50: Tensor[(64), float32], %v_param_51: Tensor[(64), float32], %v_param_52: Tensor[(64), float32], %v_param_53: Tensor[(64), float32], %v_param_54: Tensor[(64), float32], %v_param_55: Tensor[(12, 64), float32], %v_param_56: Tensor[(12), float32]) {
#   %0 = nn.conv2d(%input_5, %v_param_1, strides=[2, 2], padding=[4, 1, 5, 1], channels=64, kernel_size=[10, 4]);
#   %1 = nn.bias_add(%0, %v_param_2);
#   %2 = nn.batch_norm(%1, %v_param_3, %v_param_4, %v_param_5, %v_param_6, epsilon=0.001f);
#   %3 = %2.0;
#   %4 = nn.relu(%3);
#   %5 = nn.conv2d(%4, %v_param_7, padding=[1, 1, 1, 1], groups=64, channels=64, kernel_size=[3, 3]);
#   %6 = nn.bias_add(%5, %v_param_8);
#   %7 = nn.batch_norm(%6, %v_param_9, %v_param_10, %v_param_11, %v_param_12, epsilon=0.001f);
#   %8 = %7.0;
#   %9 = nn.relu(%8);
#   %10 = nn.conv2d(%9, %v_param_13, padding=[0, 0, 0, 0], channels=64, kernel_size=[1, 1]);
#   %11 = nn.bias_add(%10, %v_param_14);
#   %12 = nn.batch_norm(%11, %v_param_15, %v_param_16, %v_param_17, %v_param_18, epsilon=0.001f);
#   %13 = %12.0;
#   %14 = nn.relu(%13);
#   %15 = nn.conv2d(%14, %v_param_19, padding=[1, 1, 1, 1], groups=64, channels=64, kernel_size=[3, 3]);
#   %16 = nn.bias_add(%15, %v_param_20);
#   %17 = nn.batch_norm(%16, %v_param_21, %v_param_22, %v_param_23, %v_param_24, epsilon=0.001f);
#   %18 = %17.0;
#   %19 = nn.relu(%18);
#   %20 = nn.conv2d(%19, %v_param_25, padding=[0, 0, 0, 0], channels=64, kernel_size=[1, 1]);
#   %21 = nn.bias_add(%20, %v_param_26);
#   %22 = nn.batch_norm(%21, %v_param_27, %v_param_28, %v_param_29, %v_param_30, epsilon=0.001f);
#   %23 = %22.0;
#   %24 = nn.relu(%23);
#   %25 = nn.conv2d(%24, %v_param_31, padding=[1, 1, 1, 1], groups=64, channels=64, kernel_size=[3, 3]);
#   %26 = nn.bias_add(%25, %v_param_32);
#   %27 = nn.batch_norm(%26, %v_param_33, %v_param_34, %v_param_35, %v_param_36, epsilon=0.001f);
#   %28 = %27.0;
#   %29 = nn.relu(%28);
#   %30 = nn.conv2d(%29, %v_param_37, padding=[0, 0, 0, 0], channels=64, kernel_size=[1, 1]);
#   %31 = nn.bias_add(%30, %v_param_38);
#   %32 = nn.batch_norm(%31, %v_param_39, %v_param_40, %v_param_41, %v_param_42, epsilon=0.001f);
#   %33 = %32.0;
#   %34 = nn.relu(%33);
#   %35 = nn.conv2d(%34, %v_param_43, padding=[1, 1, 1, 1], groups=64, channels=64, kernel_size=[3, 3]);
#   %36 = nn.bias_add(%35, %v_param_44);
#   %37 = nn.batch_norm(%36, %v_param_45, %v_param_46, %v_param_47, %v_param_48, epsilon=0.001f);
#   %38 = %37.0;
#   %39 = nn.relu(%38);
#   %40 = nn.conv2d(%39, %v_param_49, padding=[0, 0, 0, 0], channels=64, kernel_size=[1, 1]);
#   %41 = nn.bias_add(%40, %v_param_50);
#   %42 = nn.batch_norm(%41, %v_param_51, %v_param_52, %v_param_53, %v_param_54, epsilon=0.001f);
#   %43 = %42.0;
#   %44 = nn.relu(%43);
#   %45 = nn.avg_pool2d(%44, pool_size=[24, 5], strides=[24, 5], padding=[0, 0, 0, 0]);
#   %46 = transpose(%45, axes=[0, 2, 3, 1]);
#   %47 = nn.batch_flatten(%46);
#   %48 = nn.dense(%47, %v_param_55, units=12);
#   %49 = nn.bias_add(%48, %v_param_56);
#   nn.softmax(%49, axis=1)
# }

# %% [markdown]
# # mobilenet

# %%
model = mobilenet.mobilenet_v1()
data = np.ones((1, 96, 96, 3)).astype(np.float32)
shape_dict = {"input_1": data.shape}
mod, params = relay.frontend.from_keras(model, shape_dict)
print(mod)
# Out:
# def @main(%input_6, %v_param_1: Tensor[(8, 3, 3, 3), float32], %v_param_2: Tensor[(8), float32], %v_param_3: Tensor[(8), float32], %v_param_4: Tensor[(8), float32], %v_param_5: Tensor[(8), float32], %v_param_6: Tensor[(8), float32], %v_param_7: Tensor[(8, 1, 3, 3), float32], %v_param_8: Tensor[(8), float32], %v_param_9: Tensor[(8), float32], %v_param_10: Tensor[(8), float32], %v_param_11: Tensor[(8), float32], %v_param_12: Tensor[(8), float32], %v_param_13: Tensor[(16, 8, 1, 1), float32], %v_param_14: Tensor[(16), float32], %v_param_15: Tensor[(16), float32], %v_param_16: Tensor[(16), float32], %v_param_17: Tensor[(16), float32], %v_param_18: Tensor[(16), float32], %v_param_19: Tensor[(16, 1, 3, 3), float32], %v_param_20: Tensor[(16), float32], %v_param_21: Tensor[(16), float32], %v_param_22: Tensor[(16), float32], %v_param_23: Tensor[(16), float32], %v_param_24: Tensor[(16), float32], %v_param_25: Tensor[(32, 16, 1, 1), float32], %v_param_26: Tensor[(32), float32], %v_param_27: Tensor[(32), float32], %v_param_28: Tensor[(32), float32], %v_param_29: Tensor[(32), float32], %v_param_30: Tensor[(32), float32], %v_param_31: Tensor[(32, 1, 3, 3), float32], %v_param_32: Tensor[(32), float32], %v_param_33: Tensor[(32), float32], %v_param_34: Tensor[(32), float32], %v_param_35: Tensor[(32), float32], %v_param_36: Tensor[(32), float32], %v_param_37: Tensor[(32, 32, 1, 1), float32], %v_param_38: Tensor[(32), float32], %v_param_39: Tensor[(32), float32], %v_param_40: Tensor[(32), float32], %v_param_41: Tensor[(32), float32], %v_param_42: Tensor[(32), float32], %v_param_43: Tensor[(32, 1, 3, 3), float32], %v_param_44: Tensor[(32), float32], %v_param_45: Tensor[(32), float32], %v_param_46: Tensor[(32), float32], %v_param_47: Tensor[(32), float32], %v_param_48: Tensor[(32), float32], %v_param_49: Tensor[(64, 32, 1, 1), float32], %v_param_50: Tensor[(64), float32], %v_param_51: Tensor[(64), float32], %v_param_52: Tensor[(64), float32], %v_param_53: Tensor[(64), float32], %v_param_54: Tensor[(64), float32], %v_param_55: Tensor[(64, 1, 3, 3), float32], %v_param_56: Tensor[(64), float32], %v_param_57: Tensor[(64), float32], %v_param_58: Tensor[(64), float32], %v_param_59: Tensor[(64), float32], %v_param_60: Tensor[(64), float32], %v_param_61: Tensor[(64, 64, 1, 1), float32], %v_param_62: Tensor[(64), float32], %v_param_63: Tensor[(64), float32], %v_param_64: Tensor[(64), float32], %v_param_65: Tensor[(64), float32], %v_param_66: Tensor[(64), float32], %v_param_67: Tensor[(64, 1, 3, 3), float32], %v_param_68: Tensor[(64), float32], %v_param_69: Tensor[(64), float32], %v_param_70: Tensor[(64), float32], %v_param_71: Tensor[(64), float32], %v_param_72: Tensor[(64), float32], %v_param_73: Tensor[(128, 64, 1, 1), float32], %v_param_74: Tensor[(128), float32], %v_param_75: Tensor[(128), float32], %v_param_76: Tensor[(128), float32], %v_param_77: Tensor[(128), float32], %v_param_78: Tensor[(128), float32], %v_param_79: Tensor[(128, 1, 3, 3), float32], %v_param_80: Tensor[(128), float32], %v_param_81: Tensor[(128), float32], %v_param_82: Tensor[(128), float32], %v_param_83: Tensor[(128), float32], %v_param_84: Tensor[(128), float32], %v_param_85: Tensor[(128, 128, 1, 1), float32], %v_param_86: Tensor[(128), float32], %v_param_87: Tensor[(128), float32], %v_param_88: Tensor[(128), float32], %v_param_89: Tensor[(128), float32], %v_param_90: Tensor[(128), float32], %v_param_91: Tensor[(128, 1, 3, 3), float32], %v_param_92: Tensor[(128), float32], %v_param_93: Tensor[(128), float32], %v_param_94: Tensor[(128), float32], %v_param_95: Tensor[(128), float32], %v_param_96: Tensor[(128), float32], %v_param_97: Tensor[(128, 128, 1, 1), float32], %v_param_98: Tensor[(128), float32], %v_param_99: Tensor[(128), float32], %v_param_100: Tensor[(128), float32], %v_param_101: Tensor[(128), float32], %v_param_102: Tensor[(128), float32], %v_param_103: Tensor[(128, 1, 3, 3), float32], %v_param_104: Tensor[(128), float32], %v_param_105: Tensor[(128), float32], %v_param_10 ...
#   %0 = nn.conv2d(%input_6, %v_param_1, strides=[2, 2], padding=[0, 0, 1, 1], channels=8, kernel_size=[3, 3]);
#   %1 = nn.bias_add(%0, %v_param_2);
#   %2 = nn.batch_norm(%1, %v_param_3, %v_param_4, %v_param_5, %v_param_6, epsilon=0.001f);
#   %3 = %2.0;
#   %4 = nn.relu(%3);
#   %5 = nn.conv2d(%4, %v_param_7, padding=[1, 1, 1, 1], groups=8, channels=8, kernel_size=[3, 3]);
#   %6 = nn.bias_add(%5, %v_param_8);
#   %7 = nn.batch_norm(%6, %v_param_9, %v_param_10, %v_param_11, %v_param_12, epsilon=0.001f);
#   %8 = %7.0;
#   %9 = nn.relu(%8);
#   %10 = nn.conv2d(%9, %v_param_13, padding=[0, 0, 0, 0], channels=16, kernel_size=[1, 1]);
#   %11 = nn.bias_add(%10, %v_param_14);
#   %12 = nn.batch_norm(%11, %v_param_15, %v_param_16, %v_param_17, %v_param_18, epsilon=0.001f);
#   %13 = %12.0;
#   %14 = nn.relu(%13);
#   %15 = nn.conv2d(%14, %v_param_19, strides=[2, 2], padding=[0, 0, 1, 1], groups=16, channels=16, kernel_size=[3, 3]);
#   %16 = nn.bias_add(%15, %v_param_20);
#   %17 = nn.batch_norm(%16, %v_param_21, %v_param_22, %v_param_23, %v_param_24, epsilon=0.001f);
#   %18 = %17.0;
#   %19 = nn.relu(%18);
#   %20 = nn.conv2d(%19, %v_param_25, padding=[0, 0, 0, 0], channels=32, kernel_size=[1, 1]);
#   %21 = nn.bias_add(%20, %v_param_26);
#   %22 = nn.batch_norm(%21, %v_param_27, %v_param_28, %v_param_29, %v_param_30, epsilon=0.001f);
#   %23 = %22.0;
#   %24 = nn.relu(%23);
#   %25 = nn.conv2d(%24, %v_param_31, padding=[1, 1, 1, 1], groups=32, channels=32, kernel_size=[3, 3]);
#   %26 = nn.bias_add(%25, %v_param_32);
#   %27 = nn.batch_norm(%26, %v_param_33, %v_param_34, %v_param_35, %v_param_36, epsilon=0.001f);
#   %28 = %27.0;
#   %29 = nn.relu(%28);
#   %30 = nn.conv2d(%29, %v_param_37, padding=[0, 0, 0, 0], channels=32, kernel_size=[1, 1]);
#   %31 = nn.bias_add(%30, %v_param_38);
#   %32 = nn.batch_norm(%31, %v_param_39, %v_param_40, %v_param_41, %v_param_42, epsilon=0.001f);
#   %33 = %32.0;
#   %34 = nn.relu(%33);
#   %35 = nn.conv2d(%34, %v_param_43, strides=[2, 2], padding=[0, 0, 1, 1], groups=32, channels=32, kernel_size=[3, 3]);
#   %36 = nn.bias_add(%35, %v_param_44);
#   %37 = nn.batch_norm(%36, %v_param_45, %v_param_46, %v_param_47, %v_param_48, epsilon=0.001f);
#   %38 = %37.0;
#   %39 = nn.relu(%38);
#   %40 = nn.conv2d(%39, %v_param_49, padding=[0, 0, 0, 0], channels=64, kernel_size=[1, 1]);
#   %41 = nn.bias_add(%40, %v_param_50);
#   %42 = nn.batch_norm(%41, %v_param_51, %v_param_52, %v_param_53, %v_param_54, epsilon=0.001f);
#   %43 = %42.0;
#   %44 = nn.relu(%43);
#   %45 = nn.conv2d(%44, %v_param_55, padding=[1, 1, 1, 1], groups=64, channels=64, kernel_size=[3, 3]);
#   %46 = nn.bias_add(%45, %v_param_56);
#   %47 = nn.batch_norm(%46, %v_param_57, %v_param_58, %v_param_59, %v_param_60, epsilon=0.001f);
#   %48 = %47.0;
#   %49 = nn.relu(%48);
#   %50 = nn.conv2d(%49, %v_param_61, padding=[0, 0, 0, 0], channels=64, kernel_size=[1, 1]);
#   %51 = nn.bias_add(%50, %v_param_62);
#   %52 = nn.batch_norm(%51, %v_param_63, %v_param_64, %v_param_65, %v_param_66, epsilon=0.001f);
#   %53 = %52.0;
#   %54 = nn.relu(%53);
#   %55 = nn.conv2d(%54, %v_param_67, strides=[2, 2], padding=[0, 0, 1, 1], groups=64, channels=64, kernel_size=[3, 3]);
#   %56 = nn.bias_add(%55, %v_param_68);
#   %57 = nn.batch_norm(%56, %v_param_69, %v_param_70, %v_param_71, %v_param_72, epsilon=0.001f);
#   %58 = %57.0;
#   %59 = nn.relu(%58);
#   %60 = nn.conv2d(%59, %v_param_73, padding=[0, 0, 0, 0], channels=128, kernel_size=[1, 1]);
#   %61 = nn.bias_add(%60, %v_param_74);
#   %62 = nn.batch_norm(%61, %v_param_75, %v_param_76, %v_param_77, %v_param_78, epsilon=0.001f);
#   %63 = %62.0;
#   %64 = nn.relu(%63);
#   %65 = nn.conv2d(%64, %v_param_79, padding=[1, 1, 1, 1], groups=128, channels=128, kernel_size=[3, 3]);
#   %66 = nn.bias_add(%65, %v_param_80);
#   %67 = nn.batch_norm(%66, %v_param_81, %v_param_82, %v_param_83, %v_param_84, epsilon=0.001f);
#   %68 = %67.0;
#   %69 = nn.relu(%68);
#   %70 = nn.conv2d(%69, %v_param_85, padding=[0, 0, 0, 0], channels=128, kernel_size=[1, 1]);
#   %71 = nn.bias_add(%70, %v_param_86);
#   %72 = nn.batch_norm(%71, %v_param_87, %v_param_88, %v_param_89, %v_param_90, epsilon=0.001f);
#   %73 = %72.0;
#   %74 = nn.relu(%73);
#   %75 = nn.conv2d(%74, %v_param_91, padding=[1, 1, 1, 1], groups=128, channels=128, kernel_size=[3, 3]);
#   %76 = nn.bias_add(%75, %v_param_92);
#   %77 = nn.batch_norm(%76, %v_param_93, %v_param_94, %v_param_95, %v_param_96, epsilon=0.001f);
#   %78 = %77.0;
#   %79 = nn.relu(%78);
#   %80 = nn.conv2d(%79, %v_param_97, padding=[0, 0, 0, 0], channels=128, kernel_size=[1, 1]);
#   %81 = nn.bias_add(%80, %v_param_98);
#   %82 = nn.batch_norm(%81, %v_param_99, %v_param_100, %v_param_101, %v_param_102, epsilon=0.001f);
#   %83 = %82.0;
#   %84 = nn.relu(%83);
#   %85 = nn.conv2d(%84, %v_param_103, padding=[1, 1, 1, 1], groups=128, channels=128, kernel_size=[3, 3]);
#   %86 = nn.bias_add(%85, %v_param_104);
#   %87 = nn.batch_norm(%86, %v_param_105, %v_param_106, %v_param_107, %v_param_108, epsilon=0.001f);
#   %88 = %87.0;
#   %89 = nn.relu(%88);
#   %90 = nn.conv2d(%89, %v_param_109, padding=[0, 0, 0, 0], channels=128, kernel_size=[1, 1]);
#   %91 = nn.bias_add(%90, %v_param_110);
#   %92 = nn.batch_norm(%91, %v_param_111, %v_param_112, %v_param_113, %v_param_114, epsilon=0.001f);
#   %93 = %92.0;
#   %94 = nn.relu(%93);
#   %95 = nn.conv2d(%94, %v_param_115, padding=[1, 1, 1, 1], groups=128, channels=128, kernel_size=[3, 3]);
#   %96 = nn.bias_add(%95, %v_param_116);
#   %97 = nn.batch_norm(%96, %v_param_117, %v_param_118, %v_param_119, %v_param_120, epsilon=0.001f);
#   %98 = %97.0;
#   %99 = nn.relu(%98);
#   %100 = nn.conv2d(%99, %v_param_121, padding=[0, 0, 0, 0], channels=128, kernel_size=[1, 1]);
#   %101 = nn.bias_add(%100, %v_param_122);
#   %102 = nn.batch_norm(%101, %v_param_123, %v_param_124, %v_param_125, %v_param_126, epsilon=0.001f);
#   %103 = %102.0;
#   %104 = nn.relu(%103);
#   %105 = nn.conv2d(%104, %v_param_127, padding=[1, 1, 1, 1], groups=128, channels=128, kernel_size=[3, 3]);
#   %106 = nn.bias_add(%105, %v_param_128);
#   %107 = nn.batch_norm(%106, %v_param_129, %v_param_130, %v_param_131, %v_param_132, epsilon=0.001f);
#   %108 = %107.0;
#   %109 = nn.relu(%108);
#   %110 = nn.conv2d(%109, %v_param_133, padding=[0, 0, 0, 0], channels=128, kernel_size=[1, 1]);
#   %111 = nn.bias_add(%110, %v_param_134);
#   %112 = nn.batch_norm(%111, %v_param_135, %v_param_136, %v_param_137, %v_param_138, epsilon=0.001f);
#   %113 = %112.0;
#   %114 = nn.relu(%113);
#   %115 = nn.conv2d(%114, %v_param_139, strides=[2, 2], padding=[0, 0, 1, 1], groups=128, channels=128, kernel_size=[3, 3]);
#   %116 = nn.bias_add(%115, %v_param_140);
#   %117 = nn.batch_norm(%116, %v_param_141, %v_param_142, %v_param_143, %v_param_144, epsilon=0.001f);
#   %118 = %117.0;
#   %119 = nn.relu(%118);
#   %120 = nn.conv2d(%119, %v_param_145, padding=[0, 0, 0, 0], channels=256, kernel_size=[1, 1]);
#   %121 = nn.bias_add(%120, %v_param_146);
#   %122 = nn.batch_norm(%121, %v_param_147, %v_param_148, %v_param_149, %v_param_150, epsilon=0.001f);
#   %123 = %122.0;
#   %124 = nn.relu(%123);
#   %125 = nn.conv2d(%124, %v_param_151, padding=[1, 1, 1, 1], groups=256, channels=256, kernel_size=[3, 3]);
#   %126 = nn.bias_add(%125, %v_param_152);
#   %127 = nn.batch_norm(%126, %v_param_153, %v_param_154, %v_param_155, %v_param_156, epsilon=0.001f);
#   %128 = %127.0;
#   %129 = nn.relu(%128);
#   %130 = nn.conv2d(%129, %v_param_157, padding=[0, 0, 0, 0], channels=256, kernel_size=[1, 1]);
#   %131 = nn.bias_add(%130, %v_param_158);
#   %132 = nn.batch_norm(%131, %v_param_159, %v_param_160, %v_param_161, %v_param_162, epsilon=0.001f);
#   %133 = %132.0;
#   %134 = nn.relu(%133);
#   %135 = nn.avg_pool2d(%134, pool_size=[3, 3], strides=[3, 3], padding=[0, 0, 0, 0]);
#   %136 = transpose(%135, axes=[0, 2, 3, 1]);
#   %137 = nn.batch_flatten(%136);
#   %138 = nn.dense(%137, %v_param_163, units=2);
#   %139 = nn.bias_add(%138, %v_param_164);
#   nn.softmax(%139, axis=1)
# }

# %% [markdown]
# # deep autoencoder

# %%
param = deep_autoencoder.yaml_load()
model = deep_autoencoder.get_model(
    param["feature"]["n_mels"] * param["feature"]["frames"])
data = np.ones((1, 640)).astype(np.float32)
shape_dict = {"input_1": data.shape}
mod, params = relay.frontend.from_keras(model, shape_dict)
print(mod)
# Out:
# def @main(%input_7, %v_param_1: Tensor[(128, 640), float32], %v_param_2: Tensor[(128), float32], %v_param_3: Tensor[(128), float32], %v_param_4: Tensor[(128), float32], %v_param_5: Tensor[(128), float32], %v_param_6: Tensor[(128), float32], %v_param_7: Tensor[(128, 128), float32], %v_param_8: Tensor[(128), float32], %v_param_9: Tensor[(128), float32], %v_param_10: Tensor[(128), float32], %v_param_11: Tensor[(128), float32], %v_param_12: Tensor[(128), float32], %v_param_13: Tensor[(128, 128), float32], %v_param_14: Tensor[(128), float32], %v_param_15: Tensor[(128), float32], %v_param_16: Tensor[(128), float32], %v_param_17: Tensor[(128), float32], %v_param_18: Tensor[(128), float32], %v_param_19: Tensor[(128, 128), float32], %v_param_20: Tensor[(128), float32], %v_param_21: Tensor[(128), float32], %v_param_22: Tensor[(128), float32], %v_param_23: Tensor[(128), float32], %v_param_24: Tensor[(128), float32], %v_param_25: Tensor[(8, 128), float32], %v_param_26: Tensor[(8), float32], %v_param_27: Tensor[(8), float32], %v_param_28: Tensor[(8), float32], %v_param_29: Tensor[(8), float32], %v_param_30: Tensor[(8), float32], %v_param_31: Tensor[(128, 8), float32], %v_param_32: Tensor[(128), float32], %v_param_33: Tensor[(128), float32], %v_param_34: Tensor[(128), float32], %v_param_35: Tensor[(128), float32], %v_param_36: Tensor[(128), float32], %v_param_37: Tensor[(128, 128), float32], %v_param_38: Tensor[(128), float32], %v_param_39: Tensor[(128), float32], %v_param_40: Tensor[(128), float32], %v_param_41: Tensor[(128), float32], %v_param_42: Tensor[(128), float32], %v_param_43: Tensor[(128, 128), float32], %v_param_44: Tensor[(128), float32], %v_param_45: Tensor[(128), float32], %v_param_46: Tensor[(128), float32], %v_param_47: Tensor[(128), float32], %v_param_48: Tensor[(128), float32], %v_param_49: Tensor[(128, 128), float32], %v_param_50: Tensor[(128), float32], %v_param_51: Tensor[(128), float32], %v_param_52: Tensor[(128), float32], %v_param_53: Tensor[(128), float32], %v_param_54: Tensor[(128), float32], %v_param_55: Tensor[(640, 128), float32], %v_param_56: Tensor[(640), float32]) {
#   %0 = nn.dense(%input_7, %v_param_1, units=128);
#   %1 = nn.bias_add(%0, %v_param_2);
#   %2 = nn.batch_norm(%1, %v_param_3, %v_param_4, %v_param_5, %v_param_6, epsilon=0.001f);
#   %3 = %2.0;
#   %4 = nn.relu(%3);
#   %5 = nn.dense(%4, %v_param_7, units=128);
#   %6 = nn.bias_add(%5, %v_param_8);
#   %7 = nn.batch_norm(%6, %v_param_9, %v_param_10, %v_param_11, %v_param_12, epsilon=0.001f);
#   %8 = %7.0;
#   %9 = nn.relu(%8);
#   %10 = nn.dense(%9, %v_param_13, units=128);
#   %11 = nn.bias_add(%10, %v_param_14);
#   %12 = nn.batch_norm(%11, %v_param_15, %v_param_16, %v_param_17, %v_param_18, epsilon=0.001f);
#   %13 = %12.0;
#   %14 = nn.relu(%13);
#   %15 = nn.dense(%14, %v_param_19, units=128);
#   %16 = nn.bias_add(%15, %v_param_20);
#   %17 = nn.batch_norm(%16, %v_param_21, %v_param_22, %v_param_23, %v_param_24, epsilon=0.001f);
#   %18 = %17.0;
#   %19 = nn.relu(%18);
#   %20 = nn.dense(%19, %v_param_25, units=8);
#   %21 = nn.bias_add(%20, %v_param_26);
#   %22 = nn.batch_norm(%21, %v_param_27, %v_param_28, %v_param_29, %v_param_30, epsilon=0.001f);
#   %23 = %22.0;
#   %24 = nn.relu(%23);
#   %25 = nn.dense(%24, %v_param_31, units=128);
#   %26 = nn.bias_add(%25, %v_param_32);
#   %27 = nn.batch_norm(%26, %v_param_33, %v_param_34, %v_param_35, %v_param_36, epsilon=0.001f);
#   %28 = %27.0;
#   %29 = nn.relu(%28);
#   %30 = nn.dense(%29, %v_param_37, units=128);
#   %31 = nn.bias_add(%30, %v_param_38);
#   %32 = nn.batch_norm(%31, %v_param_39, %v_param_40, %v_param_41, %v_param_42, epsilon=0.001f);
#   %33 = %32.0;
#   %34 = nn.relu(%33);
#   %35 = nn.dense(%34, %v_param_43, units=128);
#   %36 = nn.bias_add(%35, %v_param_44);
#   %37 = nn.batch_norm(%36, %v_param_45, %v_param_46, %v_param_47, %v_param_48, epsilon=0.001f);
#   %38 = %37.0;
#   %39 = nn.relu(%38);
#   %40 = nn.dense(%39, %v_param_49, units=128);
#   %41 = nn.bias_add(%40, %v_param_50);
#   %42 = nn.batch_norm(%41, %v_param_51, %v_param_52, %v_param_53, %v_param_54, epsilon=0.001f);
#   %43 = %42.0;
#   %44 = nn.relu(%43);
#   %45 = nn.dense(%44, %v_param_55, units=640);
#   nn.bias_add(%45, %v_param_56)
# }
