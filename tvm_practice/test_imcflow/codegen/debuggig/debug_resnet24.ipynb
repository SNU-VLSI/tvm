# %%
import numpy as np
import pickle
from pprint import pprint

# %%
np_dict = pickle.load(open("./resnet8_subset24_pretrained_evl/debug_executor_output_tensors.pkl", "rb"))

# %%
for k in np_dict.keys():
  print(k)

# %%
data = np_dict["tvmgen_default_fused_imcflow_fused_batch_norm_2____topo-index:95____output-num:0"]

# %%
data[0,:,0,0]

# %%
data = np_dict["tvmgen_default_fused_nn_bitpack____topo-index:100____output-num:0"]
data_view = data.view(np.int16)

# %%
data_view[0,0,0,0,0,:]
