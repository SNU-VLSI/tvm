# %%
import numpy as np
import pickle as pkl

# %%
test_output="/root/project/tvm/tvm_practice/test_imcflow/codegen/resnet8_subset03_pretrained_evl/test_outputs/output.npy"
ref_output = "/root/project/tvm/tvm_practice/test_imcflow/codegen/resnet8_subset03_pretrained_evl/test_references/cpu_reference_output.npy"
imcflow_output = np.load(test_output)
cpu_output = np.load(ref_output)

# %%
diff = imcflow_output - cpu_output

# %%
idx = np.abs(diff) > 0

# %%
idx = np.where(np.abs(diff) > 0)

# %%
idx
# Out:
# (array([0, 0, 0]), array([5, 5, 5]), array([ 0, 10, 20]), array([ 4, 27,  4]))

# %%
imcflow_output[0,5,0,4]
# Out:
# 15

# %%
cpu_output[0,5,0,5]
# Out:
# 0
